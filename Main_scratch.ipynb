# %%
from google.colab import drive
drive.mount('/content/gdrive/')
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/
# Mounted at /content/gdrive/

# %%
# !pip install -q SharedArray
# !pip install -q pypianoroll==0.5.3
#!pip install wandb

import sys
import os
import sys
sys.path.append('/content/gdrive/My Drive/GAN_test/bmusegan-master')
sys.path.append('/content/gdrive/My Drive/GAN_test/bmusegan-master/training_data')

import numpy as np

# %tensorflow_version 1.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

import SharedArray as sa
from musegan.bmusegan.models import GAN, RefineGAN, End2EndGAN
from config import EXP_CONFIG, DATA_CONFIG, MODEL_CONFIG, TRAIN_CONFIG
from config import TF_CONFIG
#import wandb
#wandb.init()
# Out:
#   Building wheel for SharedArray (setup.py) ... done
#      |████████████████████████████████| 5.6MB 24.2MB/s
#      |████████████████████████████████| 61kB 7.6MB/s
#   Building wheel for pypianoroll (setup.py) ... done
#   Building wheel for pretty-midi (setup.py) ... done
# TensorFlow 1.x selected.
# Found GPU at: /device:GPU:0
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/config.py:111: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
tf.test.is_gpu_available()
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
def load_data():
    """Load and return the training data."""
    print('[*] Loading data...')
    DATA_CONFIG['training_data'] = '/content/gdrive/My Drive/GAN_test/bmusegan-master/training_data/final-balanced-scottish-midi-data.npy'
    if DATA_CONFIG['training_data_location'] == 'sa':
        x_train = sa.attach(DATA_CONFIG['training_data'])
    elif DATA_CONFIG['training_data_location'] == 'hd':
        x_train = np.load(DATA_CONFIG['training_data'])
    x_train = x_train.reshape(
        -1, MODEL_CONFIG['num_bar'], MODEL_CONFIG['num_timestep'],
        MODEL_CONFIG['num_pitch'], MODEL_CONFIG['num_track']
    )
    print('Training set size:', len(x_train))
    return x_train

def pretrain():
    """Create and pretrain a two-stage model"""
    x_train = load_data()
    with tf.Session(config=TF_CONFIG) as sess:
        gan = GAN(sess, MODEL_CONFIG)
        gan.init_all()
        if EXP_CONFIG['pretrained_dir'] is not None:
            gan.load_latest(EXP_CONFIG['pretrained_dir'])
        gan.train(x_train, TRAIN_CONFIG)

def train():
    """Load the pretrained model and run the second-stage training"""
    x_train = load_data()
    with tf.Session(config=TF_CONFIG) as sess:
        gan = GAN(sess, MODEL_CONFIG)
        gan.init_all()
        gan.load_latest(EXP_CONFIG['first_stage_dir'])

        refine_gan = RefineGAN(sess, MODEL_CONFIG, gan)
        refine_gan.init_all()
        if EXP_CONFIG['pretrained_dir'] is not None:
            refine_gan.load_latest(EXP_CONFIG['pretrained_dir'])
        refine_gan.train(x_train, TRAIN_CONFIG)

def train_end2end():
    """Create and train an end-to-end model"""
    x_train = load_data()
    with tf.Session(config=TF_CONFIG) as sess:
        end2end_gan = End2EndGAN(sess, MODEL_CONFIG)
        end2end_gan.init_all()
        if EXP_CONFIG['pretrained_dir'] is not None:
            end2end_gan.load_latest(EXP_CONFIG['pretrained_dir'])
        end2end_gan.train(x_train, TRAIN_CONFIG)

if __name__ == '__main__':
    print("Start experiment: {}".format(EXP_CONFIG['exp_name']))
    if not EXP_CONFIG['two_stage_training']:
        train_end2end()
    elif TRAIN_CONFIG['training_phase'] == 'pretrain':
        pretrain()
    elif TRAIN_CONFIG['training_phase'] == 'train':
        train()
# Out:
# Start experiment: haggis_balancedDataset_10Epochs
# [*] Loading data...
# Training set size: 1047
# [*] Building GAN...
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:213: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:213: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:113: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:156: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:29: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:29: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:142: conv3d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv3DTranspose` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:235: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/utils/neuralnet.py:138: conv3d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv3D` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:76: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:267: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# =============================== Model Statistics ===============================
# WARNING:tensorflow:From /content/gdrive/My Drive/GAN_test/bmusegan-master/musegan/bmusegan/models.py:89: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# Number of parameters: 3735737
# Number of parameters in G: 1580440
# Number of parameters in D: 2155297
# ================================ Model Summary =================================
# ----------------------------------- < GAN > ------------------------------------
# ------------------------------------ GAN/G -------------------------------------
# Input                                             (32, 128)
# --------------------------------------------------------------------------------
# [GAN/G/shared]
# Input                                             (32, 128)
# GAN/G/shared/Layer_0                 dense        (32, 1536)
# GAN/G/shared/Layer_1                 reshape      (32, 3, 1, 1, 512)
# GAN/G/shared/Layer_2                 transconv3d  (32, 4, 1, 1, 256)
# GAN/G/shared/Layer_3                 transconv3d  (32, 4, 4, 1, 128)
# GAN/G/shared/Layer_4                 transconv3d  (32, 4, 4, 3, 128)
# GAN/G/shared/Layer_5                 transconv3d  (32, 4, 16, 3, 64)
# GAN/G/shared/Layer_6                 transconv3d  (32, 4, 16, 7, 64)
# --------------------------------------------------------------------------------
# [GAN/G/pt_0]
# Input                                             (32, 4, 16, 7, 64)
# GAN/G/pt_0/Layer_0                   transconv3d  (32, 4, 16, 84, 64)
# GAN/G/pt_0/Layer_1                   transconv3d  (32, 4, 96, 84, 32)
# --------------------------------------------------------------------------------
# [GAN/G/tp_0]
# Input                                             (32, 4, 16, 7, 64)
# GAN/G/tp_0/Layer_0                   transconv3d  (32, 4, 96, 7, 64)
# GAN/G/tp_0/Layer_1                   transconv3d  (32, 4, 96, 84, 32)
# --------------------------------------------------------------------------------
# [GAN/G/merged_0]
# Input                                             (32, 4, 96, 84, 64)
# GAN/G/merged_0/Layer_0               transconv3d  (32, 4, 96, 84, 1)
# --------------------------------------------------------------------------------
# ------------------------------------ GAN/D -------------------------------------
# Input                                             (32, 4, 96, 84, 8)
# --------------------------------------------------------------------------------
# [GAN/D/pt_0]
# Input                                             (32, 4, 96, 84, 1)
# GAN/D/pt_0/Layer_0                   conv3d       (32, 4, 96, 7, 32)
# GAN/D/pt_0/Layer_1                   conv3d       (32, 4, 16, 7, 64)
# --------------------------------------------------------------------------------
# [GAN/D/tp_0]
# Input                                             (32, 4, 96, 84, 1)
# GAN/D/tp_0/Layer_0                   conv3d       (32, 4, 16, 84, 32)
# GAN/D/tp_0/Layer_1                   conv3d       (32, 4, 16, 7, 64)
# --------------------------------------------------------------------------------
# [GAN/D/merged_0]
# Input                                             (32, 4, 16, 7, 128)
# GAN/D/merged_0/Layer_0               conv3d       (32, 4, 16, 7, 64)
# --------------------------------------------------------------------------------
# [GAN/D/shared]
# Input                                             (32, 4, 16, 7, 512)
# GAN/D/shared/Layer_0                 conv3d       (32, 4, 4, 3, 128)
# GAN/D/shared/Layer_1                 conv3d       (32, 4, 1, 1, 256)
# --------------------------------------------------------------------------------
# [GAN/D/chroma]
# Input                                             (32, 4, 4, 12, 8)
